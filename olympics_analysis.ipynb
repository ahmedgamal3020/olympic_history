# %%
import pandas as pd 
import numpy as np
import os

# %%
files=os.listdir(path='E:\data analysis\olympics_priject\olympics')

# %%
dfs=[]
for file in files :
    df=pd.read_csv(f'olympics/{file}')
    dfs.append(df)
df=pd.concat(dfs,ignore_index=True)

# %%
summer=pd.read_csv(f'olympics/summer.csv')
winter=pd.read_csv('olympics/winter.csv')
dictionary=pd.read_csv('olympics/dictionary.csv')

# %%
summer.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
summer.Year.unique()
# Out:
# array([1896, 1900, 1904, 1908, 1912, 1920, 1924, 1928, 1932, 1936, 1948,
#        1952, 1956, 1960, 1964, 1968, 1972, 1976, 1980, 1984, 1988, 1992,
#        1996, 2000, 2004, 2008, 2012], dtype=int64)

# %%
winter.head()
# Out:
#    Year      City     Sport Discipline               Athlete Country Gender  \
# 0  1924  Chamonix  Biathlon   Biathlon           BERTHET, G.     FRA    Men
# 1  1924  Chamonix  Biathlon   Biathlon        MANDRILLON, C.     FRA    Men
# 2  1924  Chamonix  Biathlon   Biathlon   MANDRILLON, Maurice     FRA    Men
# 3  1924  Chamonix  Biathlon   Biathlon       VANDELLE, André     FRA    Men
# 4  1924  Chamonix  Biathlon   Biathlon  AUFDENBLATTEN, Adolf     SUI    Men
#
#              Event   Medal
# 0  Military Patrol  Bronze
# 1  Military Patrol  Bronze
# 2  Military Patrol  Bronze
# 3  Military Patrol  Bronze
# 4  Military Patrol    Gold

# %%
winter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5770 entries, 0 to 5769
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        5770 non-null   int64
#  1   City        5770 non-null   object
#  2   Sport       5770 non-null   object
#  3   Discipline  5770 non-null   object
#  4   Athlete     5770 non-null   object
#  5   Country     5770 non-null   object
#  6   Gender      5770 non-null   object
#  7   Event       5770 non-null   object
#  8   Medal       5770 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 405.8+ KB

# %%
winter.Year.unique()
# Out:
# array([1924, 1928, 1932, 1936, 1948, 1952, 1956, 1960, 1964, 1968, 1972,
#        1976, 1980, 1984, 1988, 1992, 1994, 1998, 2002, 2006, 2010, 2014],
#       dtype=int64)

# %%
dictionary.head()
# Out:
#            Country Code  Population  GDP per Capita
# 0      Afghanistan  AFG  32526562.0      594.323081
# 1          Albania  ALB   2889167.0     3945.217582
# 2          Algeria  ALG  39666519.0     4206.031232
# 3  American Samoa*  ASA     55538.0             NaN
# 4          Andorra  AND     70473.0             NaN

# %%
dictionary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         201 non-null    object
#  1   Code            201 non-null    object
#  2   Population      196 non-null    float64
#  3   GDP per Capita  176 non-null    float64
# dtypes: float64(2), object(2)
# memory usage: 6.4+ KB

# %%
dictionary.Country
# Out:
# 0          Afghanistan
# 1              Albania
# 2              Algeria
# 3      American Samoa*
# 4              Andorra
#             ...
# 196            Vietnam
# 197    Virgin Islands*
# 198              Yemen
# 199             Zambia
# 200           Zimbabwe
# Name: Country, Length: 201, dtype: object

# %%
dictionary.Country=dictionary.Country.str.split(', ').str[::-1].str.join(' ')

# %%
dictionary
# Out:
#              Country Code  Population  GDP per Capita
# 0        Afghanistan  AFG  32526562.0      594.323081
# 1            Albania  ALB   2889167.0     3945.217582
# 2            Algeria  ALG  39666519.0     4206.031232
# 3    American Samoa*  ASA     55538.0             NaN
# 4            Andorra  AND     70473.0             NaN
# ..               ...  ...         ...             ...
# 196          Vietnam  VIE  91703800.0     2111.138024
# 197  Virgin Islands*  ISV    103574.0             NaN
# 198            Yemen  YEM  26832215.0     1406.291651
# 199           Zambia  ZAM  16211767.0     1304.879014
# 200         Zimbabwe  ZIM  15602751.0      924.143819
#
# [201 rows x 4 columns]

# %%
summer.Athlete=summer.Athlete.str.split(', ').str[::-1].str.join(' ').str.title()

# %%
summer=summer.merge(dictionary,left_on='Country',right_on='Code')

# %%
summer.drop(columns={'Code','Population','GDP per Capita'},inplace=True)

# %%
summer.rename(columns={'Country_x':'Code','Country_y':'Country'},inplace=True)

# %%
summer
# Out:
#        Year    City      Sport Discipline          Athlete Code Gender  \
# 0      1896  Athens   Aquatics   Swimming     Alfred Hajos  HUN    Men
# 1      1896  Athens   Aquatics   Swimming     Alfred Hajos  HUN    Men
# 2      1896  Athens  Athletics  Athletics  Alajos Szokolyi  HUN    Men
# 3      1896  Athens  Athletics  Athletics      Nandor Dani  HUN    Men
# 4      1896  Athens  Athletics  Athletics    Gyula Kellner  HUN    Men
# ...     ...     ...        ...        ...              ...  ...    ...
# 25737  2012  London  Athletics  Athletics   Erick Barrondo  GUA    Men
# 25738  2012  London  Athletics  Athletics     Kirani James  GRN    Men
# 25739  2012  London  Athletics  Athletics       Nijel Amos  BOT    Men
# 25740  2012  London    Sailing    Sailing  Pavlos Kontides  CYP    Men
# 25741  2012  London  Taekwondo  Taekwondo    Anthony Obame  GAB    Men
#
#                  Event   Medal    Country
# 0       100M Freestyle    Gold    Hungary
# ...

# %%
winter=winter.merge(dictionary,left_on='Country',right_on='Code')

# %%
winter.drop(columns={'Code','Population','GDP per Capita'},inplace=True)

# %%
winter.Athlete=winter.Athlete.str.split(', ').str[::-1].str.join(' ').str.title()
winter
# Out:
#       Year       City     Sport Discipline             Athlete Country_x  \
# 0     1924   Chamonix  Biathlon   Biathlon          G. Berthet       FRA
# 1     1924   Chamonix  Biathlon   Biathlon       C. Mandrillon       FRA
# 2     1924   Chamonix  Biathlon   Biathlon  Maurice Mandrillon       FRA
# 3     1924   Chamonix  Biathlon   Biathlon      André Vandelle       FRA
# 4     1924   Chamonix   Curling    Curling          H. Aldeert       FRA
# ...    ...        ...       ...        ...                 ...       ...
# 4821  2006      Turin    Skiing  Snowboard      Radoslav Zidek       SVK
# 4822  2010  Vancouver  Biathlon   Biathlon   Anastazia Kuzmina       SVK
# 4823  2010  Vancouver  Biathlon   Biathlon        Pavol Hurajt       SVK
# 4824  2010  Vancouver  Biathlon   Biathlon   Anastazia Kuzmina       SVK
# 4825  2014      Sochi  Biathlon   Biathlon   Anastazia Kuzmina       SVK
#
#      Gender            Event   Medal Country_y
# ...

# %%
winter.rename(columns={'Country_x':'Code','Country_y':'Country'},inplace=True)

# %%
winter.Country.unique()
# Out:
# array(['France', 'Switzerland', 'Finland', 'Belgium', 'United Kingdom',
#        'Sweden', 'Canada', 'United States', 'Austria', 'Norway',
#        'Germany', 'Hungary', 'Italy', 'Netherlands', 'Japan', 'Poland',
#        'North Korea', 'Spain', 'Liechtenstein', 'Bulgaria', 'South Korea',
#        'China', 'Luxembourg', 'New Zealand', 'Russia', 'Ukraine',
#        'Belarus', 'Australia', 'Slovenia', 'Kazakhstan', 'Uzbekistan',
#        'Denmark', 'Czech Republic', 'Croatia', 'Estonia', 'Latvia',
#        'Slovakia'], dtype=object)

# %%
summer.to_csv('olympics_summer.csv',index=False)
winter.to_csv('olympics_winter.csv',index=False)
